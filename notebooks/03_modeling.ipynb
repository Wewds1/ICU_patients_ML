# %% [markdown]
# # 03 Modeling
# This notebook compares logistic regression, random forest, XGBoost, and the clinical baselines.

# %% [markdown]
# ## Best model summary
# - Selected threshold: `0.25`
# - SOFA baseline AUROC: `0.552`
# - NEWS2 baseline AUROC: `0.545`

# %%
import pandas as pd
from pathlib import Path
metrics = pd.read_csv(Path('../data/processed/model_metrics.csv'))
metrics

# %% [markdown]
# ![ROC and PR Curves](../figures/model_curves.png)
#
# ![Confusion Matrix](../figures/confusion_matrix.png)
